# %% [markdown]
# ---
# layout: post
# title: Basketball Legends
# description: Imported game
# toc: false
# comments: false
# categories: [5.A, C4.1]
# courses: { compsci: {week: 5} }
# type: tangibles
# ---

# %% [markdown]
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Basketball Legends - Friv 15 Games online - Friv 15 Free Games - Friv Games Online</title>
#     <meta name="keywords" content="Friv 15, friv15, Friv 15 Games , Friv Games Online" />
#     <!-- css -->
#     <link href="https://ubg98.github.io/BasketballLegends2020/css/a1b01e734b573fca08eb1a65e6df9a384e84.css" rel="stylesheet" />
#     <!--[if IE 9]>
#     <link href="https://ubg98.github.io/BasketballLegends2020/css/601b16e72a1a56a277ea90431bd6a15e.css" rel="stylesheet" type="text/css" />
#     <![endif]-->
#     <!-- end css -->
#     <!-- javascript -->
#     <script src="https://ubg98.github.io/BasketballLegends2020/js/jquery4e84.js"></script>
#     <script src="https://ubg98.github.io/BasketballLegends2020/js/play4e84.js"></script>
#     <!-- end javascript -->
# </head>
# <body>
#     <div id="fb-root"></div>
#     <div class="backgroundTop"></div>
#     <div id="gameBox">
#         <div id="gameHeader">
#             <a href="https://ubg98.github.io/BasketballLegends2020" class="logoG" title="Basketball Legends"><img src="https://ubg98.github.io/BasketballLegends2020/img/logo.png" width="234px" alt="Basketball Legends"></a>
#             <div class="menu">
#                 <!-- Add your menu items here -->
#             </div>
#             <div>
#                 <div class="headerBanner">
#                     <!-- Add your banner code here -->
#                 </div>
#             </div>
#         </div>
#         <div class="similarGames fLeft fplay">
#             <em>Advertisement</em>
#             <!-- Add your advertisement code here -->
#         </div>
#         <div class="gameplay fplay">
#             <div class="gameName">
#                 <a href="https://ubg98.github.io/BasketballLegends2020" class="backButton" title="Basketball Legends"></a>
#                 <h1>
#                     Basketball Legends
#                 </h1>
#                 <div class="fb-like" data-layout="button" data-action="like" data-show-faces="true" data-share="true"></div>
#             </div>
#             <div class="game">
#                 <iframe src="https://ubg98.github.io/BasketballLegends2020" frameborder="0" width="760" height="575"></iframe>
#             </div>
#         </div>
#         <div class="similarGames fRight fplay">
#             <em>Advertisement</em>
#             <!-- Add your advertisement code here -->
#         </div>
#         <!-- Add your other content here -->
#     </div>
#     <div class="backgroundBottom"></div>
# </body>
# </html>

# %% [markdown]
# ---
# layout: post
# title: testing
# description: HW
# toc: false
# comments: false
# categories: [5.A, C4.1]
# courses: { compsci: {week: 26} }
# type: hacks
# ---

# %%
{
  "widget": "root",
  "accountTasks": [
    {
      "label": "Change Password",
      "uri": "/abbott/task/2997$217"
    },
    {
      "label": "Change Preferences",
      "uri": "/abbott/task/2998$2725"
    },
    {
      "label": "Manage Password Challenge Questions (Do Not Use)",
      "uri": "/abbott/task/2997$1123"
    }
  ],
  "autoCompleteSearch": true,
  "body": {
    "widget": "home",
    "iid": "6$113859",
    "enabled": false,
    "configurationUri": "/abbott/inst/1735$47/rel-task/2997$1046",
    "homeApplets": [
      {
        "widget": "homeApplet",
        "ecid": "56$527641",
        "iid": "6$113860",
        "enabled": false,
        "label": "HR Service Center",
        "iconName": "icon-tile-question-mark",
        "appletRequired": true,
        "desktopWorklet": {
          "widget": "desktopWorklet",
          "ecid": "56$527657",
          "iid": "6$113858",
          "enabled": false,
          "badgeCount": 0,
          "uri": "/abbott/inst/13102!CK5mGhIKBggDEMenAhIICgYI1A0QkwI~*WGkY6HMaiOU~/cacheable-task/3001$26",
          "workletIid": "1422$4587",
          "propertyName": "nyw:Desktop_Worklet"
        },
        "configurationInstance": "1748$275",
        "propertyName": "nyw:Worklet_Configuration_Container"
      },
      {
        "widget": "homeApplet",
        "ecid": "56$527641",
        "iid": "6$113860",
        "enabled": false,
        "label": "Personal Information",
        "iconName": "icon-tile-personalinfo",
        "appletRequired": true,
        "desktopWorklet": {
          "widget": "desktopWorklet",
          "ecid": "56$527657",
          "iid": "6$113858",
          "enabled": false,
          "badgeCount": 0,
          "uri": "/abbott/inst/13102!CK5mGhEKBggDEMenAhIHCgUI1A0QAQ~~*SOu-GPeGZ-c~/cacheable-task/2997$2151",
          "workletIid": "501$72",
          "propertyName": "nyw:Desktop_Worklet"
        },
        "configurationInstance": "1748$1",
        "propertyName": "nyw:Worklet_Configuration_Container"
      }
    ],
    "announcements": {
      "widget": "announcementGroup",
      "ecid": "56$527654",
      "iid": "6$84778",
      "enabled": false,
      "children": [
        {
          "widget": "announcement",
          "ecid": "56$423996",
          "iid": "6$44170",
          "enabled": false,
          "imageListNode": {
            "widget": "imageList",
            "ecid": "56$192246",
            "iid": "15$68934",
            "enabled": false,
            "label": "Person Image",
            "instances": [
              {
                "widget": "image",
                "instanceId": "1055$72300",
                "text": "",
                "action": "image",
                "target": "..._b21zLWF0dGFjaG1lbnRzLzJlNDExZDY3LTRjNjctNGExYi0wYzdjLTFlMDUxNTUxMDYzNT8xNzE1NDA3MjAwMDAwPz9BYmJvdHRfbXlIUlRlYW0gV29ya2xldCBMb2dvLnBuZw",
                "rt": true
              }
            ],
            "instanceMetadata": {
              "Type": "Photo"
            },
            "uriTemplate": "/abbott/attachment/[IID]/[Target]",
            "propertyName": "wd:Person_Image--IS"
          },
          "announcementTitle": {
            "widget": "text",
            "ecid": "56$192235",
            "iid": "4$13564",
            "enabled": false,
            "label": "Announcement Title",
            "value": "HR Service Center",
            "instanceMetadata": {
              "Type": "Title"
            },
            "propertyName": "wd:Announcement_Title"
          },
          "announcementText": {
            "widget": "richTextArea",
            "ecid": "56$192234",
            "iid": "2737$217",
            "enabled": false,
            "label": "Announcement Text",
            "value": "\u003Cp style=\"text-align:left\"\u003E\u003Ca target=\"_blank\" href=\"https://www.hrservicecenter.abbott.com/\"\u003EHR Service Center Website\u003C/a\u003E | \u003Ca target=\"_blank\" href=\"https://www.hrservicecenter.abbott.com/hc/en-us/articles/4404535746445\"\u003EPhone Numbers\u003C/a\u003E\u003C/p\u003E",
            "instanceMetadata": {
              "Type": "Body"
            },
            "propertyName": "wd:Announcement_Text"
          },
          "embeddedVideo": {
            "widget": "embeddedVideo",
            "url": {
              "widget": "text",
              "ecid": "56$321462",
              "iid": "4$24599",
              "enabled": false,
              "label": "Announcement Video URL",
              "propertyName": "wd:Announcement_Video_URL"
            },
            "title": {
              "widget": "text",
              "ecid": "56$321464",
              "iid": "4$24597",
              "enabled": false,
              "label": "Video Title",
              "propertyName": "wd:Video_Title"
            },
            "description": {
              "widget": "text",
              "ecid": "56$321463",
              "iid": "4$24598",
              "enabled": false,
              "label": "Video Description",
              "propertyName": "wd:Video_Description"
            },
            "previewImage": {
              "widget": "imageList",
              "ecid": "56$321465",
              "iid": "3$37347",
              "enabled": false,
              "label": "Image",
              "uriTemplate": "/abbott/attachment/[IID]/[Target]",
              "propertyName": "wd:Announcement.has_video_preview_Image--IS"
            }
          },
          "propertyName": "wd:Announcement"
        },
        {
          "widget": "announcement",
          "ecid": "56$423996",
          "iid": "6$44170",
          "enabled": false,
          "imageListNode": {
            "widget": "imageList",
            "ecid": "56$192246",
            "iid": "15$68934",
            "enabled": false,
            "label": "Person Image",
            "instances": [
              {
                "widget": "image",
                "instanceId": "1055$148656",
                "text": "",
                "action": "image",
                "target": "..._b21zLWF0dGFjaG1lbnRzLzRkNjExNTczLTc3NzAtNDAxNC0yNDBkLTI4NzczODdkMDAyND8xNzE1NDA3MjAwMDAwPz9jaGVja2NpcmNsZV9wcmltYXJ5LWJsdWVfbHJnLnBuZw",
                "rt": true
              }
            ],
            "instanceMetadata": {
              "Type": "Photo"
            },
            "uriTemplate": "/abbott/attachment/[IID]/[Target]",
            "propertyName": "wd:Person_Image--IS"
          },
          "announcementTitle": {
            "widget": "text",
            "ecid": "56$192235",
            "iid": "4$13564",
            "enabled": false,
            "label": "Announcement Title",
            "value": "COVID-19 Vaccination Information/Exemption Request",
            "instanceMetadata": {
              "Type": "Title"
            },
            "propertyName": "wd:Announcement_Title"
          },
          "announcementText": {
            "widget": "richTextArea",
            "ecid": "56$192234",
            "iid": "2737$217",
            "enabled": false,
            "label": "Announcement Text",
            "instanceMetadata": {
              "Type": "Body"
            },
            "propertyName": "wd:Announcement_Text"
          },
          "embeddedVideo": {
            "widget": "embeddedVideo",
            "url": {
              "widget": "text",
              "ecid": "56$321462",
              "iid": "4$24599",
              "enabled": false,
              "label": "Announcement Video URL",
              "propertyName": "wd:Announcement_Video_URL"
            },
            "title": {
              "widget": "text",
              "ecid": "56$321464",
              "iid": "4$24597",
              "enabled": false,
              "label": "Video Title",
              "propertyName": "wd:Video_Title"
            },
            "description": {
              "widget": "text",
              "ecid": "56$321463",
              "iid": "4$24598",
              "enabled": false,
              "label": "Video Description",
              "propertyName": "wd:Video_Description"
            },
            "previewImage": {
              "widget": "imageList",
              "ecid": "56$321465",
              "iid": "3$37347",
              "enabled": false,
              "label": "Image",
              "uriTemplate": "/abbott/attachment/[IID]/[Target]",
              "propertyName": "wd:Announcement.has_video_preview_Image--IS"
            }
          },
          "link": {
            "widget": "monikerList",
            "ecid": "56$411770",
            "iid": "15$375159",
            "enabled": false,
            "label": "Announcement Quicklink Item",
            "instances": [
              {
                "widget": "moniker",
                "instanceId": "3395$997",
                "text": "COVID-19 Vaccination Information/Exemption Request",
                "action": "URL",
                "target": "https%3A%2F%2Fwd5.myworkday.com%2Fabbott%2Fd%2Finst%2F13102%21CK5mGhIKBggDEMenAhIICgYI1A0QqQI%7E*aW4qj-pGeC0%7E%2Fcacheable-task%2F3001%2426.htmld%23backheader%3Dtrue",
                "rt": true
              }
            ],
            "selfUriTemplate": "/abbott/inst/15$375159/3395$997",
            "relatedTasksUriTemplate": "/abbott/inst/3395$997/rel-tasks",
            "propertyName": "wd:Announcement_Quicklink_Item--IS",
            "singular": true
          },
          "propertyName": "wd:Announcement"
        },
        {
          "widget": "announcement",
          "ecid": "56$423996",
          "iid": "6$44170",
          "enabled": false,
          "imageListNode": {
            "widget": "imageList",
            "ecid": "56$192246",
            "iid": "15$68934",
            "enabled": false,
            "label": "Person Image",
            "instances": [
              {
                "widget": "image",
                "instanceId": "1055$72314",
                "text": "",
                "action": "image",
                "target": "..._b21zLWF0dGFjaG1lbnRzLzJiNTA1OTY0LTU4MzMtNDI1NS0wZDVkLTExM2QzMzMxMTAyNz8xNzE1NDA3MjAwMDAwPz9BYmJvdHQgU2lnbmF0dXJlX3ZlcnRpY2FsXzUwMHg1MDAuanBn",
                "rt": true
              }
            ],
            "instanceMetadata": {
              "Type": "Photo"
            },
            "uriTemplate": "/abbott/attachment/[IID]/[Target]",
            "propertyName": "wd:Person_Image--IS"
          },
          "announcementTitle": {
            "widget": "text",
            "ecid": "56$192235",
            "iid": "4$13564",
            "enabled": false,
            "label": "Announcement Title",
            "value": "Getting Started at Abbott",
            "instanceMetadata": {
              "Type": "Title"
            },
            "propertyName": "wd:Announcement_Title"
          },
          "announcementText": {
            "widget": "richTextArea",
            "ecid": "56$192234",
            "iid": "2737$217",
            "enabled": false,
            "label": "Announcement Text",
            "value": "\u003Cp style=\"text-align:left\"\u003E\u003Cspan\u003EWelcome to Abbott!\u003C/span\u003E\u003C/p\u003E\u003Cp style=\"text-align:inherit\"\u003E\u003C/p\u003E\u003Cp style=\"text-align:left\"\u003E\u003Cspan\u003ETake a moment to explore the different sections of Onboarding. Please click on the word \u003C/span\u003E\u003C/p\u003E\u003Cp style=\"text-align:left\"\u003E\u003Cspan\u003E\"Onboarding\"\u003C/span\u003E\u003C/p\u003E",
            "instanceMetadata": {
              "Type": "Body"
            },
            "propertyName": "wd:Announcement_Text"
          },
          "embeddedVideo": {
            "widget": "embeddedVideo",
            "url": {
              "widget": "text",
              "ecid": "56$321462",
              "iid": "4$24599",
              "enabled": false,
              "label": "Announcement Video URL",
              "propertyName": "wd:Announcement_Video_URL"
            },
            "title": {
              "widget": "text",
              "ecid": "56$321464",
              "iid": "4$24597",
              "enabled": false,
              "label": "Video Title",
              "propertyName": "wd:Video_Title"
            },
            "description": {
              "widget": "text",
              "ecid": "56$321463",
              "iid": "4$24598",
              "enabled": false,
              "label": "Video Description",
              "propertyName": "wd:Video_Description"
            },
            "previewImage": {
              "widget": "imageList",
              "ecid": "56$321465",
              "iid": "3$37347",
              "enabled": false,
              "label": "Image",
              "uriTemplate": "/abbott/attachment/[IID]/[Target]",
              "propertyName": "wd:Announcement.has_video_preview_Image--IS"
            }
          },
          "button": {
            "widget": "commandButton",
            "ecid": "56$586947",
            "label": "Onboarding",
            "values": [
              {
                "label": "Onboarding",
                "uri": "/abbott/task/14860$26",
                "taskId": "14860$26",
                "httpMethod": "GET"
              }
            ],
            "uri": "/abbott/task/14860$26",
            "taskId": "14860$26",
            "httpMethod": "GET",
            "actionId": "view",
            "rule": 2,
            "footerOrder": 0,
            "layoutInstanceId": "3009$7176",
            "propertyName": "wd:Action_Label_2",
            "layoutId": "3009$7176"
          },
          "propertyName": "wd:Announcement"
        }
      ],
      "propertyName": "nyw:Landing_Page_Announcements"
    },
    "informationText": {
      "widget": "richTextArea",
      "ecid": "56$527651",
      "iid": "2737$213",
      "enabled": false,
      "propertyName": "nyw:Landing_Page_Information_Text"
    },
    "configurationLabel": "Configure this page",
    "propertyName": "nyw:Home_Page"
  },
  "brandingData": {
    "banner": {
      "uri": "/abbott/attachment/17214$..._b21zLWF0dGFjaG1lbnRzLzZhMmU2MDJjLTRkMWUtNDc3NC0xNTE5LTExNjY1YjIyMDMyOD8xNzE1NDA3MjAwMDAwP2ltYWdlL3BuZz9Xb3JkYXlfYmFubmVyX0FiYm90dC1sb2dvXzE0NDB4MTkzLnBuZzswLDAsMTQ0MCwxOTM",
      "width": 1440,
      "height": 193
    },
    "bannerSmall": {
      "uri": "/abbott/attachment/19202$..._b21zLWF0dGFjaG1lbnRzLzcxN2I3NTFmLTRjNjItNDQwNy0xNjc2LTM3NzM2YzMxNTkzMz8xNzE1NDA3MjAwMDAwP2ltYWdlL3BuZz9Xb3JkYXlfYmFubmVyXzgyOHgyNzYtMDEucG5nOzQ1OSwxOCwzNDksMjQ5",
      "width": 349,
      "height": 249
    },
    "canvasColor": {
      "widget": "color",
      "instanceId": "21484$116",
      "text": "Blueberry 500",
      "action": "color-picker",
      "target": "#005cb9,#0875e1",
      "rt": true
    },
    "canvasColorSource": "#005cb9,#0875e1",
    "arrCanvasColorShades": [
      "#D7E9FC",
      "#A6D2FF",
      "#409FFF",
      "#0874E1",
      "#005cb9",
      "#004387"
    ],
    "defaultBrandingColor": true
  },
  "clearPageContextUri": "/abbott/clear-page-context/c2",
  "commandLinkTemplate": "/abbott/task/[IID]",
  "currentTime": 1715403492119,
  "currentUser": {
    "widget": "currentUser",
    "iid": "247$369411",
    "label": "Tejas Manoj",
    "relatedTasksLink": {
      "widget": "link",
      "rel": "related-tasks",
      "uri": "/abbott/inst/247$369411/rel-tasks",
      "pv": true,
      "rt": true
    },
    "selfLink": {
      "widget": "link",
      "rel": "self",
      "uri": "/abbott/inst/1$37/247$369411",
      "v": true
    },
    "userImageUrl": "/abbott/attachment/1055$..._b21zLWF0dGFjaG1lbnRzLzMwNTg3MzA1LTA4NzMtNGUxNC0zNzFhLTBkNDM2MzcyMjk1Mj8xNzE1NDA3MjAwMDAwP2ltYWdlL2pwZWc_VGVqYXMgTWFub2ogKDEpLkpQRzsxODQsMjA5LDE3NTcsMTc1Nw"
  },
  "enableContentDeliveryNetwork": true,
  "enablePdfAndExcel": true,
  "enableSpInitiatedSamlAuthentication": true,
  "failedSignonCount": 0,
  "gettingStartedGuide": {
    "disableUrl": "/getting-started-guide/7598$5/disable"
  },
  "globalHelpUrl": "/abbott/help/helpHome.xml?langcode=en_US",
  "header": {
    "widget": "header",
    "excelLink": {
      "widget": "link",
      "label": "Excel",
      "httpMethod": "GET",
      "type": "EXPORT_EXCEL",
      "uri": "/abbott/export/c2.xlsx",
      "requestParameters": [
        {
          "widget": "requestParameter",
          "key": "page-title",
          "value": "Home"
        }
      ]
    },
    "pdfLink": {
      "widget": "link",
      "httpMethod": "POST",
      "type": "PRINT_PDF",
      "uri": "/abbott/print/c2",
      "requestParameters": [
        {
          "widget": "requestParameter",
          "key": "page-title",
          "value": "Home"
        }
      ]
    }
  },
  "homePages": [
    {
      "label": "Home",
      "rule": "2997$6670",
      "uri": "/abbott/home/2997$6670",
      "default": true,
      "selected": true
    }
  ],
  "homeUri": "/abbott/d/home.htmld",
  "locale": "en_US",
  "localeAttributes": {
    "amPmPrefixPosition": "0",
    "amString": "AM",
    "dateOrder": "MM/dd/yyyy",
    "dateToolTip": "MM/DD/YYYY",
    "decimalSeparator": ".",
    "firstDayOfWeek": "sun",
    "hourClock": "12",
    "percentSymbolLeft": "0",
    "percentSymbolSpace": "0",
    "pmString": "PM",
    "thousandsSeparator": ",",
    "userLocale": "en_US",
    "workdayMonthRange": "LLLL1 - LLLL2",
    "workdayYearMonthFormat": "LLLL y"
  },
  "loginRedirectUrl": "https://wd5.myworkday.com/abbott/login-saml2.htmld",
  "logoutRedirectUrl": "https://wd5.myworkday.com/abbott/login.htmld",
  "logoutUri": "https://wd5.myworkday.com/wday/authgwy/abbott/logout.htmld",
  "mediaMarkingText": "Abbott Proprietary & Confidential",
  "navigationLinks": [
    {
      "label": "Favorites",
      "rule": "Nav.Favorites",
      "uri": "/abbott/task/2997$83"
    },
    {
      "label": "My Reports",
      "rule": "W Drive",
      "uri": "/abbott/task/2997$1605"
    }
  ],
  "omsEnvironmentType": "PROD",
  "pageAutomationIid": "15$172879",
  "processingUser": "12358792",
  "promptUriTemplate": "/abbott/prompt/[CONTEXT_ID]/[PROMPT_IID]",
  "enabled": false,
  "requestUri": "/abbott/home.htmld",
  "searchScopesUri": "/abbott/search-scopes.xml",
  "searchUri": "/abbott/search.htmld",
  "sessionSecureToken": "9eeca959-ce11-4298-9155-e600f980e47d",
  "sessionTimeoutMinutes": 90,
  "sessionUserClickable": true,
  "systemStatusMessage": "Your system will be unavailable for a maximum of 3 hours during the next Weekly Service Update; starting on Friday, May 10, 2024 at 11:00 PM PDT (GMT-7) until Saturday, May 11, 2024 at 2:00 AM PDT (GMT-7).",
  "taskId": "2997$6670",
  "activePageTaskId": "2997$6670",
  "teaserTasks": [
    {
      "label": "Unified Inbox Action Items count",
      "type": "action_items_count",
      "uri": "/abbott/unifiedinbox/actioncount/2998$18348"
    },
    {
      "label": "My Tasks (All Items)",
      "type": "skeleton",
      "uri": "/abbott/unifiedinbox/initialinbox/2998$44084"
    },
    {
      "label": "Notifications",
      "type": "Notification_Inbox_Preview_Skeleton_Task--IS",
      "uri": "/abbott/task/2998$34445"
    },
    {
      "label": "Notifications",
      "type": "Notification_Inbox_Skeleton_Task--IS",
      "uri": "/abbott/unifiedinbox/initialinbox/2998$23221"
    }
  ],
  "tenant": "abbott",
  "timeoutRedirectUrl": "https://wd5.myworkday.com/wday/authgwy/abbott/timeout.htmld",
  "timeZoneExternalName": "Pacific Time (Los Angeles)",
  "timeZoneInternalName": "TZ005",
  "timeZoneName": "US/Pacific",
  "timeZoneOffset": "-420",
  "timeZoneUrl": "/abbott/timezones.xml",
  "title": {
    "widget": "titleStaticText",
    "text": "Home"
  },
  "userLanguageCode": "en_US",
  "xmlName": "Home_Page",
  "instanceSelfLinkTemplate": "/abbott/inst/[CONTEXT_ID]/[IID]",
  "instanceTaskLinkTemplate": "/abbott/inst/[IID]/rel-task/[Task_IID]",
  "relatedTasksLinkTemplate": "/abbott/inst/[IID]/rel-tasks",
  "taskLinkTemplate": "/abbott/task/[Task_IID]",
  "stepUpSecondsRemaining": 0,
  "pageContextId": "c2",
  "enableModalEnhancements": true,
  "localeCode": "en_US",
  "uiLabels": {
    "WDRES.DIRECTORY.EnterACharacterToBegin": "Enter a character to begin",
    "WDRES.ANNOUNCEMENTS.Announcements": "Announcements",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.TalentPerformanceTitle": "{0} has hit a new performance ~goal~!",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.AbsenceLeaveMessage": "{0} is currently on a leave of absence.",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.AnniversaryMessage": "Don't forget to say congratulations!",
    "WDRES.HOME.ExternalLinks": "External Links",
    "WDRES.TIMECLOCK.Tasks": "Tasks",
    "WDRES.HOME.ConfigureApplicationsButton": "Configure Applications",
    "WDRES.DASHBOARD.NMore": "(+{0} More)",
    "WDRES.SCREENREADER.YourProfile": "Your Profile",
    "WDRES.SCREENREADER.HomeBottomNav": "{0} of {1}",
    "WDRES.DIRECTORY.Collapse": "Collapse",
    "WDRES.DIRECTORY.ShowAll": "Show All",
    "WDRES.HOMEPAGE.ViewApps": "View Apps",
    "WDRES.HOMEPAGE.FrequentlyUsed": "Frequently Used",
    "WDRES.HOMEPAGE.Apps": "Apps",
    "WDRES.SCREENREADER.ToggleView": "Toggle View",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.TimeOffTitle": "Team Member Time Off",
    "WDRES.HOMEPAGE.1NewItem": "1 New Item",
    "WDRES.QUICKACCESS.QuickAccessIntroductionMessage": "Get to your favorite places from anywhere in Workday.",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.AnniversaryTitle": "It’s {0}’s {1} today!",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.CompensationTitle": "{0} has a change in compensation.",
    "WDRES.DIRECTORY.CoWorkers": "Co-workers",
    "WDRES.SCREENREADER.VideoDescription": "Video Description",
    "WDRES.HOME.ONBOARDING.YourNewWorkdayHome": "Your New Workday Home",
    "WDRES.HOMEPAGE.NextPayment": "Next Payment",
    "WDRES.SCREENREADER.VideoTitle": "Video Title",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.MilestoneTitle": "{0} has hit a new milestone!",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.FeedbackMessage": "Be sure to follow up.",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.MilestoneMessage": "Don’t forget to congratulate them and provide feedback.",
    "WDRES.SCREENREADER.AnnouncementTitle": "Announcement Title",
    "WDRES.TIMEOFF.NoApprovedTimeOff": "No approved Absence",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.BirthdayTitle": "It’s {0}’s birthday today!",
    "WDRES.HOMEPAGE.ViewPayslips": "View Payslips",
    "WDRES.TIMEOFF.TimeOff": "Time Off",
    "WDRES.HOME.ShowPreview": "Show Preview",
    "WDRES.HOMEPAGE.NNewItems": "{0} New Items",
    "WDRES.SCREENREADER.AnnouncementDescription": "Announcement Description",
    "WDRES.SETTINGS.UseDeviceBiometrics": "Use Device Biometrics",
    "WDRES.WORKERPROFILE.Team": "Team",
    "WDRES.HOME.ONBOARDING.NavigationBar": "Navigation Bar",
    "WDRES.HOMEPAGE.ViewAnnouncements": "View Announcements",
    "WDRES.DIRECTORY.TypeThreeLettersToBegin": "Type three letters to begin",
    "WDRES.DIRECTORY.searchForPeople": "Search for People",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.TimeOffMessage": "{0} is currently on time off from work.",
    "WDRES.HOME.GoToInbox": "Go to Inbox",
    "WDRES.SCREENREADER.NavigationDrawer": "Navigation Drawer",
    "WDRES.QUICKACCESS.APIErrorMessage": "An unexpected error has occurred. Try again later.",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.FeedbackTitle": "Feedback has been received on {0}.",
    "WDRES.FACETEDSEARCH.People": "People",
    "WDRES.HOME.WelcomeName": "Welcome, {0}",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.ChangeJobMessage": "{0} is now {1}.",
    "WDRES.HOME.ONBOARDING.AllYourApps": "All your favorite Workday Apps, still in one place.",
    "WDRES.QUICKACCESS.QuickAccessIntroductionHeader": "Introducing Quick Access",
    "WDRES.HOME.Applications": "Applications",
    "WDRES.QUICKACCESS.OpenQuickAccessButton": "Open Quick Access",
    "WDRES.HOMEPAGE.NoNewItems": "No New Items",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.AbsenceLeaveTitle": "Team Member Leave of Absence",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.BirthdayMessage": "Remember to wish them a happy birthday.",
    "WDRES.TIMEOFF.RequestTimeOff": "Review Your Calendar",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.TeamCalendarMessage": "It’s a significant day for one of your teammates. Be sure to find out and follow up with them today!",
    "WDRES.HOMEPAGE.EditHomePage": "Edit Home Page",
    "WDRES.HOME.Welcome": "Welcome",
    "WDRES.HOMEPAGE.LastPayment": "Last Payment",
    "WDRES.HOME.HidePreview": "Hide Preview",
    "WDRES.CALENDAR.ViewBalances": "View Balances",
    "WDRES.HOMEPAGE.Pay": "Pay",
    "WDRES.PAYSLIPS.NoRecentPayslips": "No recent payslips",
    "WDRES.SCREENREADER.Video": "Video",
    "WDRES.HOME.ONBOARDING.AccessCardData": "Access Frequently Used, Payslips, and other important data, directly from cards on your home screen.",
    "WDRES.SCREENREADER.NAnnouncements": "{0} Announcements",
    "WDRES.SCREENREADER.SelectAll": "Select All",
    "WDRES.HOME.ONBOARDING.NavigateBetween": "Navigate between your home, inbox, notifications and Workday apps from the new bottom bar.",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.TalentPerformanceMessage": "Be sure to follow up with {0}.",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.ChangeJobTitle": "{0} has a new position!",
    "WDRES.ANNOUNCEMENTS.TEAMCALENDAR.TeamCalendarTitle": "Team Member Event",
    "WDRES.WORKERPROFILE.MyTeam": "My Team"
  },
  "viewPage": true,
  "pexEnabledForUser": true,
  "mode": "VIEW"
}
